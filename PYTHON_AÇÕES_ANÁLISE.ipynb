# %% [markdown]
# <a href="https://colab.research.google.com/github/ABGeov/ABGeov/blob/main/PYTHON_A%C3%87%C3%95ES_AN%C3%81LISE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px

# %%
df_principal = pd.read_excel("/content/Imersão Python -Ações.xlsx",sheet_name="Principal")
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)  Var. Sem. (%)  Var. Mês (%)  \
# 0   ABEV3 2024-01-26        13.20          0.00          -1.12         -3.86
# 1   ALOS3 2024-01-26        24.62         -0.28           0.53         -7.27
# 2   ALPA4 2024-01-26         8.67         -1.36           4.08        -14.33
# 3   ARZZ3 2024-01-26        57.91          1.15          -1.03        -10.26
# 4   ASAI3 2024-01-26        13.80         -1.42          -3.50          2.00
# ..    ...        ...          ...           ...            ...           ...
# 76  VAMO3 2024-01-26         8.18          0.12          -3.76        -18.77
# 77  VBBR3 2024-01-26        23.23         -0.47           2.43          2.07
# 78  VIVT3 2024-01-26        51.20          0.88           1.09         -4.19
# 79  WEGE3 2024-01-26        33.17         -0.24          -0.93        -10.13
# 80  YDUQ3 2024-01-26        19.77          1.28          -5.90        -11.82
#
#     Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume
# 0          -3.86          0.30     13.15     13.29   86,92 M
# 1          -7.27         39.82     24.53     24.92   34,33 M
# 2         -14.33        -34.52      8.62      8.80      14 M
# 3         -10.26        -28.97     56.22     59.29  202,83 M
# 4           2.00        -34.02     13.63     14.00   79,67 M
# ..           ...           ...       ...       ...       ...
# 76        -18.77        -40.74      8.11      8.27   41,64 M
# 77          2.07         50.65     22.97     23.40   58,22 M
# 78         -4.19         32.78     50.62     51.26   64,92 M
# 79        -10.13        -11.84     33.04     33.50  127,36 M
# 80        -11.82        108.45     18.99     19.78   63,48 M
#
# [81 rows x 11 columns]

# %%
df_Total_de_acoes = pd.read_excel("/content/Imersão Python -Ações.xlsx",sheet_name="Total_de_acoes")
df_Total_de_acoes
# Out:
#                       Código  Qtde. Teórica
# 0                      RRRP3   2.356656e+08
# 1                      ALOS3   5.326166e+08
# 2                      ALPA4   1.767340e+08
# 3                      ABEV3   4.394246e+09
# 4                      ARZZ3   6.230589e+07
# ..                       ...            ...
# 84                     VBBR3   1.114413e+09
# 85                     WEGE3   1.481593e+09
# 86                     YDUQ3   2.893479e+08
# 87  Quantidade Teórica Total   9.637210e+10
# 88                   Redutor   1.704785e+07
#
# [89 rows x 2 columns]

# %%
df_Ticker = pd.read_excel("/content/Imersão Python -Ações.xlsx",sheet_name="Ticker")
df_Ticker
# Out:
#     Ticker              Nome
# 0    AALR3          Alliança
# 1    ABCB4  Banco ABC Brasil
# 2    ABEV3             Ambev
# 3    AERI3      Aeris Energy
# 4    AESB3        AES Brasil
# ..     ...               ...
# 530  WIZS3             WIZS3
# 531  WLMM3               WLM
# 532  WLMM4               WLM
# 533  YDUQ3             YDUQS
# 534  ZAMP3              Zamp
#
# [535 rows x 2 columns]

# %%
df_chatgpt= pd.read_excel("/content/Imersão Python -Ações.xlsx",sheet_name="ChatGPT")
df_chatgpt
# Out:
#    Nome da empresa          Segmento  Idade (anos)
# 0     3R Petroleum          Petróleo            10
# 1            ALOS3  Telecomunicações             9
# 2       Alpargatas              Moda           113
# 3            Ambev           Bebidas            32
# 4           Arezzo              Moda            50
# ..             ...               ...           ...
# 73            Vale         Mineração            79
# 74   Vibra Energia           Energia             8
# 75            Vivo  Telecomunicações            18
# 76             WEG         Automação            59
# 77           YDUQS          Educação            59
#
# [78 rows x 3 columns]

# %%
df_principal = df_principal[['Ativo', 'Data', 'Último (R$)', 'Var. Dia (%)']].copy()
df_principal
# Out:
#     Ativo       Data  Último (R$)  Var. Dia (%)
# 0
YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
#
#     Qtde. Teórica   Variacao_rs
# 0      4394245879          0.00
# 1       532616595  -36819552.34
# 2       176733968  -21126374.33
# 3        62305891   41021792.09
# 4      1349217892 -268201195.09
# ..            ...           ...
# 76      421383330    4131341.16
# 77     1114412532 -122247236.67
# 78      423091712  188965307.06
# 79     1481593024 -118230410.44
# 80      289347914   72295838.99
#
# [81 rows x 8 columns]

# %%
df_principal = df_principal.rename(columns={'Qtde. Teórica':'Qtd_teorica'}).copy()
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   ABEV3 2024-01-26        13.20         0.00     0.00          13.20
# 1   ALOS3 2024-01-26        24.62        -0.28    -0.00          24.69
# 2   ALPA4 2024-01-26         8.67        -1.36    -0.01           8.79
# 3   ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 4   ASAI3 2024-01-26        13.80        -1.42    -0.01          14.00
# ..    ...        ...          ...          ...      ...            ...
# 76  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
# 77  VBBR3 2024-01-26        23.23        -0.47    -0.00          23.34
# 78  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 79  WEGE3 2024-01-26        33.17        -0.24    -0.00          33.25
# 80  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
#
#     Qtd_teorica   Variacao_rs
# 0    4394245879          0.00
# 1     532616595  -36819552.34
# 2     176733968  -21126374.33
# 3      62305891   41021792.09
# 4    1349217892 -268201195.09
# ..          ...           ...
# 76    421383330    4131341.16
# 77   1114412532 -122247236.67
# 78    423091712  188965307.06
# 79   1481593024 -118230410.44
# 80    289347914   72295838.99
#
# [81 rows x 8 columns]

# %%
df_principal['Resultado']= df_principal['Variacao_rs'].apply(lambda x:'Subiu' if x >0 else ('Desceu'if x <0 else 'Estável'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   ABEV3 2024-01-26        13.20         0.00     0.00          13.20
# 1   ALOS3 2024-01-26        24.62        -0.28    -0.00          24.69
# 2   ALPA4 2024-01-26         8.67        -1.36    -0.01           8.79
# 3   ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 4   ASAI3 2024-01-26        13.80        -1.42    -0.01          14.00
# ..    ...        ...          ...          ...      ...            ...
# 76  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
# 77  VBBR3 2024-01-26        23.23        -0.47    -0.00          23.34
# 78  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 79  WEGE3 2024-01-26        33.17        -0.24    -0.00          33.25
# 80  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
#
#     Qtd_teorica   Variacao_rs Resultado
# 0    4394245879          0.00   Estável
# 1     532616595  -36819552.34    Desceu
# 2     176733968  -21126374.33    Desceu
# 3      62305891   41021792.09     Subiu
# 4    1349217892 -268201195.09    Desceu
# ..          ...           ...       ...
# 76    421383330    4131341.16     Subiu
# 77   1114412532 -122247236.67    Desceu
# 78    423091712  188965307.06     Subiu
# 79   1481593024 -118230410.44    Desceu
# 80    289347914   72295838.99     Subiu
#
# [81 rows x 9 columns]

# %%
df_principal=df_principal.merge(df_Ticker, left_on='Ativo', right_on='Ticker', how='left')
df_principal=df_principal.drop(columns=['Ticker'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   ABEV3 2024-01-26        13.20         0.00     0.00          13.20
# 1   ALOS3 2024-01-26        24.62        -0.28    -0.00          24.69
# 2   ALPA4 2024-01-26         8.67        -1.36    -0.01           8.79
# 3   ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 4   ASAI3 2024-01-26        13.80        -1.42    -0.01          14.00
# ..    ...        ...          ...          ...      ...            ...
# 76  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
# 77  VBBR3 2024-01-26        23.23        -0.47    -0.00          23.34
# 78  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 79  WEGE3 2024-01-26        33.17        -0.24    -0.00          33.25
# 80  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
#
#     Qtd_teorica   Variacao_rs Resultado           Nome
# 0    4394245879          0.00   Estável          Ambev
# 1     532616595  -36819552.34    Desceu          ALOS3
# 2     176733968  -21126374.33    Desceu     Alpargatas
# 3      62305891   41021792.09     Subiu         Arezzo
# 4    1349217892 -268201195.09    Desceu          Assaí
# ..          ...           ...       ...            ...
# 76    421383330    4131341.16     Subiu    Grupo Vamos
# 77   1114412532 -122247236.67    Desceu  Vibra Energia
# 78    423091712  188965307.06     Subiu           Vivo
# 79   1481593024 -118230410.44    Desceu            WEG
# 80    289347914   72295838.99     Subiu          YDUQS
#
# [81 rows x 10 columns]

# %%
df_principal = df_principal.merge(df_chatgpt, left_on='Nome', right_on='Nome da empresa', how='left')
df_principal = df_principal.drop(columns=['Nome da empresa'])
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   ABEV3 2024-01-26        13.20         0.00     0.00          13.20
# 1   ALOS3 2024-01-26        24.62        -0.28    -0.00          24.69
# 2   ALPA4 2024-01-26         8.67        -1.36    -0.01           8.79
# 3   ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 4   ASAI3 2024-01-26        13.80        -1.42    -0.01          14.00
# ..    ...        ...          ...          ...      ...            ...
# 76  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
# 77  VBBR3 2024-01-26        23.23        -0.47    -0.00          23.34
# 78  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 79  WEGE3 2024-01-26        33.17        -0.24    -0.00          33.25
# 80  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
#
#     Qtd_teorica   Variacao_rs Resultado           Nome          Segmento  \
# 0    4394245879          0.00   Estável          Ambev           Bebidas
# 1     532616595  -36819552.34    Desceu          ALOS3  Telecomunicações
# 2     176733968  -21126374.33    Desceu     Alpargatas              Moda
# 3      62305891   41021792.09     Subiu         Arezzo              Moda
# 4    1349217892 -268201195.09    Desceu          Assaí            Varejo
# ..          ...           ...       ...            ...               ...
# 76    421383330    4131341.16     Subiu    Grupo Vamos         Logística
# 77   1114412532 -122247236.67    Desceu  Vibra Energia           Energia
# 78    423091712  188965307.06     Subiu           Vivo  Telecomunicações
# 79   1481593024 -118230410.44    Desceu            WEG         Automação
# 80    289347914   72295838.99     Subiu          YDUQS          Educação
#
#     Idade (anos)
# 0             32
# 1              9
# 2            113
# 3             50
# 4             49
# ..           ...
# 76            57
# 77             8
# 78            18
# 79            59
# 80            59
#
# [81 rows x 12 columns]

# %%
df_principal['Cat_idade'] = df_principal['Idade (anos)'].apply(lambda x: 'Mais de 100' if x > 100 else ('Menos de 50' if x < 50 else 'Entre 50 e 100'))
df_principal
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 0   ABEV3 2024-01-26        13.20         0.00     0.00          13.20
# 1   ALOS3 2024-01-26        24.62        -0.28    -0.00          24.69
# 2   ALPA4 2024-01-26         8.67        -1.36    -0.01           8.79
# 3   ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 4   ASAI3 2024-01-26        13.80        -1.42    -0.01          14.00
# ..    ...        ...          ...          ...      ...            ...
# 76  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
# 77  VBBR3 2024-01-26        23.23        -0.47    -0.00          23.34
# 78  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 79  WEGE3 2024-01-26        33.17        -0.24    -0.00          33.25
# 80  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
#
#     Qtd_teorica   Variacao_rs Resultado           Nome          Segmento  \
# 0    4394245879          0.00   Estável          Ambev           Bebidas
# 1     532616595  -36819552.34    Desceu          ALOS3  Telecomunicações
# 2     176733968  -21126374.33    Desceu     Alpargatas              Moda
# 3      62305891   41021792.09     Subiu         Arezzo              Moda
# 4    1349217892 -268201195.09    Desceu          Assaí            Varejo
# ..          ...           ...       ...            ...               ...
# 76    421383330    4131341.16     Subiu    Grupo Vamos         Logística
# 77   1114412532 -122247236.67    Desceu  Vibra Energia           Energia
# 78    423091712  188965307.06     Subiu           Vivo  Telecomunicações
# 79   1481593024 -118230410.44    Desceu            WEG         Automação
# 80    289347914   72295838.99     Subiu          YDUQS          Educação
#
#     Idade (anos)       Cat_idade
# 0             32     Menos de 50
# 1              9     Menos de 50
# 2            113     Mais de 100
# 3             50  Entre 50 e 100
# 4             49     Menos de 50
# ..           ...             ...
# 76            57  Entre 50 e 100
# 77             8     Menos de 50
# 78            18     Menos de 50
# 79            59  Entre 50 e 100
# 80            59  Entre 50 e 100
#
# [81 rows x 13 columns]

# %%
# Calculando o maior valor
maior = df_principal['Variacao_rs'].max()

# Calculando o menor valor
menor = df_principal['Variacao_rs'].min()

# Calculando a média
media = df_principal['Variacao_rs'].mean()

# Calculando a média de quem subiu
media_subiu = df_principal[df_principal['Resultado'] == 'Subiu']['Variacao_rs'].mean()

# Calculando a média de quem desceu
media_desceu = df_principal[df_principal['Resultado'] == 'Desceu']['Variacao_rs'].mean()

# Imprimindo os resultados
print(f"Maior\tR$ {maior:,.2f}")
print(f"Menor\tR$ {menor:,.2f}")
print(f"Média\tR$ {media:,.2f}")
print(f"Média de quem subiu\tR$ {media_subiu:,.2f}")
print(f"Média de quem desceu\tR$ {media_desceu:,.2f}")
# Out:
# Maior	R$ 4,762,926,995.25
# Menor	R$ -1,807,432,634.46
# Média	R$ 165,190,210.48
# Média de quem subiu	R$ 448,164,250.23
# Média de quem desceu	R$ -181,109,141.75

# %%
df_principal_subiu = df_principal[df_principal['Resultado'] == 'Subiu']
df_principal_subiu
# Out:
#     Ativo       Data  valor_final  var_dia_pct  Var_pct  valor_inicial  \
# 3   ARZZ3 2024-01-26        57.91         1.15     0.01          57.25
# 5   AZUL4 2024-01-26        14.27         1.42     0.01          14.07
# 7   BBAS3 2024-01-26        56.97         0.68     0.01          56.59
# 8   BBDC3 2024-01-26        13.75         0.36     0.00          13.70
# 9   BBDC4 2024-01-26        15.52         1.04     0.01          15.36
# 11  BEEF3 2024-01-26         7.19         0.98     0.01           7.12
# 13  BRAP4 2024-01-26        23.22         0.73     0.01          23.05
# 14  BRFS3 2024-01-26        14.61         0.96     0.01          14.47
# 15  BRKM5 2024-01-26        18.55         1.42     0.01          18.29
# 17  CIEL3 2024-01-26         4.90         0.82     0.01           4.86
# 19  CMIN3 2024-01-26         6.82         2.40     0.02           6.66
# 21  CPFE3 2024-01-26        37.10         2.03     0.02          36.36
# 22  CPLE6 2024-01-26        10.07         0.19     0.00          10.05
# 24  CSAN3 2024-01-26        18.57         0.59     0.01          18.46
# 25  CSNA3 2024-01-26        18.16         1.33     0.01          17.92
# 28  DXCO3 2024-01-26         7.81         0.77     0.01           7.75
# 34  EQTL3 2024-01-26        35.32         1.34     0.01          34.85
# 37  GGBR4 2024-01-26        21.84         0.27     0.00          21.78
# 38  GOAU4 2024-01-26        10.08         0.59     0.01          10.02
# 43  ITSA4 2024-01-26        10.01         0.70     0.01           9.94
# 44  ITUB4 2024-01-26        32.81         1.48     0.01          32.33
# 45  JBSS3 2024-01-26        24.34         0.57     0.01          24.20
# 47  LWSA3 2024-01-26         5.55         0.72     0.01           5.51
# 48  MGLU3 2024-01-26         2.08         0.48     0.00           2.07
# 50  MRVE3 2024-01-26         8.08         1.25     0.01           7.98
# 51  MULT3 2024-01-26        28.19         1.58     0.02          27.75
# 53  PCAR3 2024-01-26         4.14         0.97     0.01           4.10
# 54  PETR3 2024-01-26        41.96         2.19     0.02          41.06
# 55  PETR4 2024-01-26        39.96         1.73     0.02          39.28
# 57  PRIO3 2024-01-26        45.69         1.98     0.02          44.80
# 58  RADL3 2024-01-26        26.16         0.61     0.01          26.00
# 59  RAIL3 2024-01-26        22.64         0.84     0.01          22.45
# 60  RAIZ4 2024-01-26         3.74         0.26     0.00           3.73
# 61  RDOR3 2024-01-26        27.56         1.43     0.01          27.17
# 62  RECV3 2024-01-26        23.83         0.71     0.01          23.66
# 64  RRRP3 2024-01-26        28.75         1.41     0.01          28.35
# 69  SUZB3 2024-01-26        52.91         2.04     0.02          51.85
# 70  TIMS3 2024-01-26        17.52         0.74     0.01          17.39
# 73  UGPA3 2024-01-26        28.31         1.28     0.01          27.95
# 74  USIM5 2024-01-26         9.50         5.20     0.05           9.03
# 75  VALE3 2024-01-26        69.50         1.66     0.02          68.37
# 76  VAMO3 2024-01-26         8.18         0.12     0.00           8.17
# 78  VIVT3 2024-01-26        51.20         0.88     0.01          50.75
# 80  YDUQ3 2024-01-26        19.77         1.28     0.01          19.52
#
#     Qtd_teorica   Variacao_rs Resultado                  Nome  \
# 3      62305891   41021792.09     Subiu                Arezzo
# 5     327593725   65452205.55     Subiu                  Azul
# 7    1420949112  546752087.99     Subiu       Banco do Brasil
# 8    1500728902   74019610.05     Subiu        Banco Bradesco
# 9    5146576868  822148336.41     Subiu        Banco Bradesco
# 11    261036182   18214628.10     Subiu               Minerva
# 13    251003438   42238249.54     Subiu             Bradespar
# 14   1677525446  233045769.57     Subiu                   BRF
# 15    265877867   69054317.64     Subiu               Braskem
# 17   1095462329   43657683.38     Subiu                 Cielo
# 19   1110559345  177515970.30     Subiu         CSN Mineração
# 21    187732538  138573955.06     Subiu          CPFL Energia
# 22   1679335290   32069789.50     Subiu                 Copel
# 24   1168097881  127229653.18     Subiu                 Cosan
# 25    600865451  143220991.46     Subiu  Siderúrgica Nacional
# 28    302768240   18068446.61     Subiu                 Dexco
# 34   1095587251  511671895.45     Subiu    Equatorial Energia
# 37   1118525506   65779607.10     Subiu                Gerdau
# 38    660411219   39045606.94     Subiu    Metalúrgica Gerdau
# 43   5372783971  373853994.88     Subiu                Itaúsa
# 44   4801593832 2297591984.33     Subiu         Itaú Unibanco
# 45   1134986472  156573285.43     Subiu                   JBS
# 47    393173139   15598886.65     Subiu               Locaweb
# 48   2867627068   28493619.27     Subiu        Magazine Luiza
# 50    376187582   37525872.38     Subiu                   MRV
# 51    268505432  117732680.08     Subiu             Multiplan
# 53    159430826    6340916.22     Subiu   Grupo Pão de Açúcar
# 54   2379877655 2140059393.53     Subiu             Petrobras
# 55   4566445852 3103136291.22     Subiu             Petrobras
# 57    800010734  709687498.18     Subiu              PetroRio
# 58   1275798515  202352473.74     Subiu          RaiaDrogasil
# 59   1218352541  229771333.63     Subiu                  Rumo
# 60   1193047233   11571106.42     Subiu                Raízen
# 61   1168230366  453917907.01     Subiu             Rede D'Or
# 62    275005663   46201006.00     Subiu        PetroRecôncavo
# 64    235665566   94204643.35     Subiu          3R Petroleum
# 69    683452836  722946282.71     Subiu                Suzano
# 70    807896814  103972807.37     Subiu                   TIM
# 73   1086411192  388705223.96     Subiu              Ultrapar
# 74    515117391  241889725.43     Subiu              Usiminas
# 75   4196924316 4762926995.25     Subiu                  Vale
# 76    421383330    4131341.16     Subiu           Grupo Vamos
# 78    423091712  188965307.06     Subiu                  Vivo
# 80    289347914   72295838.99     Subiu                 YDUQS
#
#               Segmento  Idade (anos)       Cat_idade
# 3                 Moda            50  Entre 50 e 100
# 5              Aviação            13     Menos de 50
# 7                Banco           213     Mais de 100
# 8                Banco            78  Entre 50 e 100
# 9                Banco            78  Entre 50 e 100
# 11           Alimentos            29     Menos de 50
# 13             Holding            40     Menos de 50
# 14           Alimentos            11     Menos de 50
# 15             Química            19     Menos de 50
# 17  Meios de Pagamento            24     Menos de 50
# 19           Mineração             8     Menos de 50
# 21             Energia           109     Mais de 100
# 22             Energia            67  Entre 50 e 100
# 24             Energia            84  Entre 50 e 100
# 25          Siderurgia            80  Entre 50 e 100
# 28         Imobiliário             8     Menos de 50
# 34             Energia            23     Menos de 50
# 37          Siderurgia           121     Mais de 100
# 38          Siderurgia           121     Mais de 100
# 43             Holding            54  Entre 50 e 100
# 44               Banco            13     Menos de 50
# 45           Alimentos            64  Entre 50 e 100
# 47          Tecnologia            24     Menos de 50
# 48              Varejo            64  Entre 50 e 100
# 50          Construção            41     Menos de 50
# 51    Shopping Centers            48     Menos de 50
# 53              Varejo            72  Entre 50 e 100
# 54            Petróleo            69  Entre 50 e 100
# 55            Petróleo            69  Entre 50 e 100
# 57            Petróleo             9     Menos de 50
# 58              Varejo           117     Mais de 100
# 59           Logística            12     Menos de 50
# 60             Energia             8     Menos de 50
# 61               Saúde            48     Menos de 50
# 62            Petróleo            11     Menos de 50
# 64            Petróleo            10     Menos de 50
# 69    Papel e Celulose            94  Entre 50 e 100
# 70    Telecomunicações            25     Menos de 50
# 73             Energia            83  Entre 50 e 100
# 74          Siderurgia            60  Entre 50 e 100
# 75           Mineração            79  Entre 50 e 100
# 76           Logística            57  Entre 50 e 100
# 78    Telecomunicações            18     Menos de 50
# 80            Educação            59  Entre 50 e 100

# %%
df_analise_segmento = df_principal_subiu.groupby('Segmento')['Variacao_rs'].sum().reset_index()
df_analise_segmento
# Out:
#               Segmento   Variacao_rs
# 0            Alimentos  407833683.09
# 1              Aviação   65452205.55
# 2                Banco 3740512018.78
# 3           Construção   37525872.38
# 4             Educação   72295838.99
# 5              Energia 1209821623.57
# 6              Holding  416092244.42
# 7          Imobiliário   18068446.61
# 8            Logística  233902674.79
# 9   Meios de Pagamento   43657683.38
# 10           Mineração 4940442965.55
# 11                Moda   41021792.09
# 12    Papel e Celulose  722946282.71
# 13            Petróleo 6093288832.26
# 14             Química   69054317.64
# 15               Saúde  453917907.01
# 16    Shopping Centers  117732680.08
# 17          Siderurgia  489935930.93
# 18          Tecnologia   15598886.65
# 19    Telecomunicações  292938114.42
# 20              Varejo  237187009.24

# %%
df_analise_saldo = df_principal.groupby('Resultado')['Variacao_rs'].sum().reset_index()
df_analise_saldo
# Out:
#   Resultado    Variacao_rs
# 0    Desceu -6338819961.32
# 1   Estável           0.00
# 2     Subiu 19719227010.14

# %%
fig = px.bar(df_analise_saldo, x='Resultado', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Resultado')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0d56675b-273f-4bfd-b730-479de03a7956" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0d56675b-273f-4bfd-b730-479de03a7956")) {                    Plotly.newPlot(                        "0d56675b-273f-4bfd-b730-479de03a7956",                        [{"alignmentgroup":"True","hovertemplate":"Resultado=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[-6338819961.31535,0.0,19719227010.14191],"textposition":"auto","x":["Desceu","Est\u00e1vel","Subiu"],"xaxis":"x","y":[-6338819961.31535,0.0,19719227010.14191],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}] ...

# %%
fig = px.pie(df_analise_segmento, names='Segmento', values='Variacao_rs', title='Variação Reais por Segmento')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f462c604-dcf5-4754-8780-966a22bfe370" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f462c604-dcf5-4754-8780-966a22bfe370")) {                    Plotly.newPlot(                        "f462c604-dcf5-4754-8780-966a22bfe370",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segmento=%{label}\u003cbr\u003eVariacao_rs=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Alimentos","Avia\u00e7\u00e3o","Banco","Constru\u00e7\u00e3o","Educa\u00e7\u00e3o","Energia","Holding","Imobili\u00e1rio","Log\u00edstica","Meios de Pagamento","Minera\u00e7\u00e3o","Moda","Papel e Celulose","Petr\u00f3leo","Qu\u00edmica","Sa\u00fade","Shopping Centers","Siderurgia","Tecnologia","Telecomunica\u00e7\u00f5es","Varejo"],"legendgroup":"","name":"","showlegend":true,"values":[407833683.0924499,65452205.552800186,3740512018.783452,37525872.37728388,72295838.98616095,1209821623.5672965,416092244.423763,18068446.60998324,233902674.79257408,43657683.37554085,4940442965.550434,41021792.09077153,722946282.7090385,6093288832.2628355,69054317.63603853,453917907.01324,117732680.0784251,489935930.9283229,15598886.650556229,292938114.42357796,237187009.23736662],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"out ...

# %%
df_analise_cat_idade = df_principal.groupby('Cat_idade')['Variacao_rs'].sum().reset_index()
df_analise_cat_idade
# Out:
#         Cat_idade    Variacao_rs
# 0  Entre 50 e 100 11203676198.47
# 1     Mais de 100  -202408309.86
# 2     Menos de 50  2379139160.21

# %%
fig = px.bar(df_analise_cat_idade, x='Cat_idade', y='Variacao_rs', text='Variacao_rs', title='Variação Reais por Categoria de Idade')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6b608ced-b4e3-4b1e-a0d2-bbb983e89c84" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b608ced-b4e3-4b1e-a0d2-bbb983e89c84")) {                    Plotly.newPlot(                        "6b608ced-b4e3-4b1e-a0d2-bbb983e89c84",                        [{"alignmentgroup":"True","hovertemplate":"Cat_idade=%{x}\u003cbr\u003eVariacao_rs=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[11203676198.474775,-202408309.86218917,2379139160.213975],"textposition":"auto","x":["Entre 50 e 100","Mais de 100","Menos de 50"],"xaxis":"x","y":[11203676198.474775,-202408309.86218917,2379139160.213975],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"ove ...
